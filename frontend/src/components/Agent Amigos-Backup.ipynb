# %%
# Agent Amigos Backup
**Date:** December 10, 2025

## Project Structure
- **Frontend:** React + Vite (port 5173)
- **Backend:** FastAPI + Python (port 8080)

## Key Features
- 🤖 AI-Powered Desktop Assistant
- 🎮 Game Trainer Console with Cheat Engine Export
- 📊 Finance Console (Crypto/Stocks)
- 🌐 Scraper Workbench
- 📁 File Management Console
- 🎤 Voice Input Support
- 📎 File Attachment for AI Analysis

## Components
1. `App.jsx` - Main application (5492 lines)
2. `GameTrainerConsole.jsx` - Memory scanner & CE export
3. `FinanceConsole.jsx` - Crypto/Stock tracking
4. `ScraperWorkbench.jsx` - Web scraping tools
5. `FileManagementConsole.jsx` - File browser & analysis
6. `InternetConsole.jsx` - News & search
7. `MapConsole.jsx` - Maps integration

## Launch Commands
```bash
# Backend
cd backend && python agent_init.py

# Frontend
cd frontend && npm run dev -- --port 5173
```

## URLs
- Frontend: http://localhost:5173
- Backend: http://127.0.0.1:8080

# %%
# Backup timestamp and file inventory
import os
from datetime import datetime

backup_date = datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"Agent Amigos Backup - {backup_date}")
print("=" * 50)

# Key files to track
key_files = [
    "frontend/src/App.jsx",
    "frontend/src/components/GameTrainerConsole.jsx",
    "frontend/src/components/FinanceConsole.jsx",
    "frontend/src/components/FileManagementConsole.jsx",
    "frontend/src/components/ScraperWorkbench.jsx",
    "backend/agent_init.py",
    "backend/tools/file_tools.py",
    "backend/trainer/profile_store.py",
]

print("\nKey Files Status:")
for f in key_files:
    path = f"C:/Users/user/AgentAmigos/{f}"
    if os.path.exists(path):
        size = os.path.getsize(path)
        print(f"✅ {f} ({size:,} bytes)")
    else:
        print(f"❌ {f} (NOT FOUND)")
